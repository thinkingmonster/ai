# %% [markdown]
# Learning LLM from scratch

# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown,display

# %% [markdown]
# load .env file that we created and validate it has necessary keys

# %%
#constants
OLLAMA_API="http://localhost:11434/api/chat"
HEADERS={"Content-Type": "application/json"}
MODEL="llama3.2"

# %%
messages = [{"role":"user","content":"Describe some of the business applications of generative AI"}]

# %%
payload ={
    "model":MODEL,
    "messages":messages,
    "stream": False
}

# %%
response = requests.post(OLLAMA_API,json=payload,headers=HEADERS)
print(response.json()["message"]['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can be used to generate high-quality content such as articles, social media posts, product descriptions, and even entire books. This can help businesses save time and resources, while also improving the quality of their content.
# 2. **Product Design**: Generative AI can be used to design new products, such as furniture, electronics, or clothing. This can help businesses reduce design costs and improve the speed of product development.
# 3. **Customer Service Chatbots**: Generative AI can be used to power chatbots that can understand customer queries and provide personalized responses. This can help businesses improve their customer service experience and reduce the workload for human customer support agents.
# 4. **Marketing Automation**: Generative AI can be used to automate marketing tasks such as email campaigns, social media posts, and lead generation. This can help businesses save time and resources, while also improving the effectiveness of their marketing efforts.
# 5. **Data Analysis**: Generative AI can be used to analyze large datasets and identify patterns and trends that may not be visible to human analysts. This can help businesses gain insights into customer behavior, preferences, and needs.
# 6. **Financial Modeling**: Generative AI can be used to build financial models that can forecast revenue and expenses, identify potential risks, and optimize business performance.
# 7. **Language Translation**: Generative AI can be used to translate languages in real-time, improving communication with customers and partners from diverse linguistic backgrounds.
# 8. **Image and Video Generation**: Generative AI can be used to generate high-quality images and videos that can be used for marketing, advertising, or entertainment purposes.
# 9. **Predictive Maintenance**: Generative AI can be used to predict equipment failures and schedule maintenance activities, reducing downtime and improving overall efficiency.
# 10. **Cybersecurity Threat Detection**: Generative AI can be used to detect and respond to cybersecurity threats in real-time, improving the security posture of businesses.
#
# Some specific examples of companies using generative AI include:
#
# * **Amazon**: Uses generative AI to personalize product recommendations on its platform
# * **Google**: Uses generative AI to improve search results and generate new content
# * **IBM**: Uses generative AI to optimize business processes and improve customer service
# * **Microsoft**: Uses generative AI to automate tasks such as data entry and content creation
#
# These are just a few examples of the many businesses that are using generative AI to drive innovation, efficiency, and growth.

# %% [markdown]
# ```

# %%
import ollama
response = ollama.chat(model=MODEL,messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can create high-quality, personalized content such as blog posts, articles, social media posts, and even entire books. This can be especially useful for businesses that need to produce large amounts of content quickly and efficiently.
# 2. **Product Design and Development**: Generative AI can help with product design, prototyping, and testing by generating 3D models, textures, and colors. It can also aid in the development of new products by suggesting innovative designs and features.
# 3. **Image and Video Generation**: Generative AI can create realistic images and videos that can be used for marketing, advertising, or entertainment purposes. For example, companies can use generative AI to generate product images or videos without needing expensive photography equipment.
# 4. **Music Composition and Sound Design**: Generative AI can compose music, sound effects, and even entire scores for films and video games. This can save time and resources for music producers and composers.
# 5. **Chatbots and Customer Service**: Generative AI-powered chatbots can provide personalized customer service, answer frequently asked questions, and even resolve simple issues on their own.
# 6. **Predictive Analytics and Forecasting**: Generative AI can analyze large datasets and predict future trends, allowing businesses to make more informed decisions about investments, pricing, and resource allocation.
# 7. **Marketing and Advertising**: Generative AI can help with market research, segmentation, and personalization by analyzing customer data and behavior. It can also generate targeted advertising campaigns and social media content.
# 8. **Data Augmentation**: Generative AI can augment existing datasets by generating new, synthetic data that can be used for training machine learning models or improving model performance.
# 9. **Cybersecurity**: Generative AI-powered systems can detect and respond to security threats in real-time, helping businesses protect themselves against cyberattacks.
# 10. **Virtual Reality (VR) and Augmented Reality (AR)**: Generative AI can generate realistic environments, characters, and objects for VR and AR experiences, enabling new applications such as training simulations and interactive storytelling.
#
# Some specific industries that are heavily impacted by generative AI include:
#
# * Finance: Generative AI can help with risk assessment, portfolio management, and financial forecasting.
# * Healthcare: Generative AI can aid in medical research, disease diagnosis, and personalized treatment plans.
# * E-commerce: Generative AI can optimize product recommendations, pricing, and inventory management.
# * Education: Generative AI can create personalized learning materials, adaptive assessments, and intelligent tutoring systems.
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.
